# %%
import os 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import shutil 
from tqdm import tqdm
import nibabel as nib

# %%
ge_copd = pd.read_csv("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/dcm2nii/scan.csv")
ge_copd.sort_values(by = ['PatientID'], inplace = True)
ge_copd.reset_index(drop = True, inplace = True)
ge_copd
# Out:
#            PatientID  StudyDate Modality  BodyPart        Manufacturer  \
# 0    COPDGene_A16009   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 1    COPDGene_A16009   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 2    COPDGene_A24802   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 3    COPDGene_A24802   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 4    COPDGene_A27373   19000101       CT       NaN  GE MEDICAL SYSTEMS
# ..               ...        ...      ...       ...                 ...
# 181  COPDGene_Q42739   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 182  COPDGene_Q53485   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 183  COPDGene_Q53485   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 184  COPDGene_Q53566   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 185  COPDGene_Q53566   19000101       CT       NaN  GE MEDICAL SYSTEMS
#
#      Spacing  NumSlice  NumDICOM  ScanLength  \
# 0      0.625       522       522     326.250
# 1      0.625       507       507     316.875
# 2      0.625       584       584     365.000
# 3      0.625       489       489     305.625
# 4      0.625       521       521     325.625
# ..       ...       ...       ...         ...
# 181    0.625       490       490     306.250
# 182    0.625       465       465     290.625
# 183    0.625       393       393     245.625
# 184    0.625       492       492     307.500
# 185    0.625       442       442     276.250
#
#                                              SeriesUID ConvolutionKernel  \
# 0    1.2.840.113619.2.55.3.3852317604.741.128769737...              BONE
# 1    1.2.840.113619.2.55.3.3852317604.741.128769737...          STANDARD
# 2    1.2.840.113619.2.55.3.2831167752.727.122840803...              BONE
# 3    1.2.840.113619.2.55.3.2831167752.727.122840803...          STANDARD
# 4          1.2.840.113619.2.25.4.476785.1234986127.214              BONE
# ..                                                 ...               ...
# 181  1.2.840.113619.2.108.3994720393.25664.12807305...              BONE
# 182  1.2.840.113619.2.55.3.2831167752.160.127557716...              BONE
# 183  1.2.840.113619.2.55.3.2831167752.160.127557716...          STANDARD
# 184  1.2.840.113619.2.108.1627440376.19952.12410426...              BONE
# 185  1.2.840.113619.2.108.1627440376.20406.12410432...          STANDARD
#
#      SliceThickness    KVP  Reconstruction Diameter  Exposure Time  \
# 0             0.625  120.0                    322.0            500
# 1             0.625  120.0                    322.0            500
# 2             0.625  120.0                    360.0            500
# 3             0.625  120.0                    360.0            500
# 4             0.625  120.0                    320.0            478
# ..              ...    ...                      ...            ...
# 181           0.625  120.0                    360.0            478
# 182           0.625  120.0                    380.0            500
# 183           0.625  120.0                    380.0            500
# 184           0.625  120.0                    360.0            505
# 185           0.625  120.0                    360.0            478
#
#      X-Ray Tube Current  Exposure  Spiral Pitch Factor
# 0                   400         4                1.375
# 1                   100         1                1.375
# 2                   400         2                1.375
# 3                   100         0                1.375
# 4                   400         9                1.375
# ..                  ...       ...                  ...
# 181                 400         9                1.375
# 182                 400         2                1.375
# 183                 100         0                1.375
# 184                 400         9                1.375
# 185                 100         2                1.375
#
# [186 rows x 18 columns]

# %%
series_uid = ge_copd['SeriesUID'].to_list()

for file in series_uid:
    image = file + ".nii.gz"
    nibimg = nib.load(os.path.join("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/dcm2nii/NIfTI", image))
    img = nibimg.get_fdata()
    print(image, nib.orientations.aff2axcodes(nibimg.affine))
# Out:
# 1.2.840.113619.2.55.3.3852317604.741.1287697370.94.nii.gz ('L', 'A', 'S')
# 1.2.840.113619.2.55.3.3852317604.741.1287697370.618.5.nii.gz ('L', 'A', 'S')
# 1.2.840.113619.2.55.3.2831167752.727.1228408034.892.nii.gz ('L', 'A', 'S')
# 1.2.840.113619.2.55.3.2831167752.727.1228408036.99.12.nii.gz ('L', 'A', 'S')
# 1.2.840.113619.2.25.4.476785.1234986127.214.nii.gz ('L', 'A', 'S')
# 1.2.840.113619.2.55.3.3852317604.390.1271975989.734.5.nii.gz ('L', 'A', 'S')
# 1.2.840.113619.2.55.3.3852317604.390.1271975989.252.nii.gz ('L', 'A', 'S')
# 1.2.840.113619.2.108.3994720393.8979.1239618990.503.nii.gz ('L', 'A', 'S')
# 1.2.840.113619.2.108.3994720393.8979.1239618987.455.nii.gz ('L', 'A', 'S')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_601874/1217373032.py in <module>
#       5     if image in os.listdir("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/dcm2nii/NIfTI"):
#       6         nibimg = nib.load(os.path.join("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/dcm2nii/NIfTI", image))
# ----> 7         img = nibimg.get_fdata()
#       8         print(image, nib.orientations.aff2axcodes(nibimg.affine))
#       9
#
# ~/anaconda/envs/lung2/lib/python3.7/site-packages/nibabel/dataobj_images.py in get_fdata(self, caching, dtype)
#     353         # For array proxies, will attempt to confine data array to dtype
#     354         # during scaling
# --> 355         data = np.asanyarray(self._dataobj, dtype=dtype)
#     356         if caching == 'fill':
#     357             self._fdata_cache = data
#
# ~/anaconda/envs/lung2/lib/python3.7/site-packages/nibabel/arrayproxy.py in __array__(self, dtype)
#     389             Scaled image data with type `dtype`.
#     390         """
# --> 391         arr = self._get_scaled(dtype=dtype, slicer=())
#     392         if dtype is not None:
#     393             arr = arr.astype(dtype, copy=False)
#
# ~/anaconda/envs/lung2/lib/python3.7/site-packages/nibabel/arrayproxy.py in _get_scaled(self, dtype, slicer)
#     356             scl_inter = scl_inter.astype(use_dtype)
#     357         # Read array and upcast as necessary for big slopes, intercepts
# --> 358         scaled = apply_read_scaling(self._get_unscaled(slicer=slicer), scl_slope, scl_inter)
#     359         if dtype is not None:
#     360             scaled = scaled.astype(np.promote_types(scaled.dtype, dtype), copy=False)
#
# ~/anaconda/envs/lung2/lib/python3.7/site-packages/nibabel/arrayproxy.py in _get_unscaled(self, slicer)
#     335                                        offset=self._offset,
#     336                                        order=self.order,
# --> 337                                        mmap=self._mmap)
#     338         with self._get_fileobj() as fileobj:
#     339             return fileslice(fileobj,
#
# ~/anaconda/envs/lung2/lib/python3.7/site-packages/nibabel/volumeutils.py in array_from_file(shape, in_dtype, infile, offset, order, mmap)
#     520     if hasattr(infile, 'readinto'):
#     521         data_bytes = bytearray(n_bytes)
# --> 522         n_read = infile.readinto(data_bytes)
#     523         needs_copy = False
#     524     else:
#
# ~/anaconda/envs/lung2/lib/python3.7/gzip.py in read(self, size)
#     285             import errno
#     286             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 287         return self._buffer.read(size)
#     288
#     289     def read1(self, size=-1):
#
# ~/anaconda/envs/lung2/lib/python3.7/_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# ~/anaconda/envs/lung2/lib/python3.7/gzip.py in read(self, size)
#     480             buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
#     481
# --> 482             uncompress = self._decompressor.decompress(buf, size)
#     483             if self._decompressor.unconsumed_tail != b"":
#     484                 self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:
