# %% [markdown]
# ## GOLD classification for COPD subjects followed by Train, valid, test, split for COPD GENE BONE kernel subjects after curating paired kernel dataset

# %%
import pandas as pd 
import os 
import shutil
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the dataframes from the csv files 
copd_ge_initial = pd.read_csv("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/final_paired_data_spreadsheets/COPD_GE_pairedkernels_initial_sampling.csv")
copd_ge_additional = pd.read_csv("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/final_paired_data_spreadsheets/COPD_GE_pairedkernels_additional_sampling.csv")

#Merge the two dataframes 
copd_ge = pd.concat([copd_ge_initial, copd_ge_additional])
copd_ge = copd_ge.reset_index(drop=True)
copd_ge
# Out:
#            PatientID  StudyDate Modality  BodyPart        Manufacturer  \
# 0    COPDGene_A16009   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 1    COPDGene_A16009   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 2    COPDGene_A24802   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 3    COPDGene_A24802   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 4    COPDGene_A43240   19000101       CT       NaN  GE MEDICAL SYSTEMS
# ..               ...        ...      ...       ...                 ...
# 263  COPDGene_P19505   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 264  COPDGene_Q59293   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 265  COPDGene_Q59293   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 266  COPDGene_Q70095   19000101       CT       NaN  GE MEDICAL SYSTEMS
# 267  COPDGene_Q70095   19000101       CT       NaN  GE MEDICAL SYSTEMS
#
#      Spacing  NumSlice  NumDICOM  ScanLength  \
# 0      0.625     522.0     522.0     326.250
# 1      0.625     507.0     507.0     316.875
# 2      0.625     584.0     584.0     365.000
# 3      0.625     489.0     489.0     305.625
# 4      0.625     469.0     469.0     293.125
# ..       ...       ...       ...         ...
# 263    0.625     503.0     503.0     314.375
# 264    0.625     432.0     432.0     270.000
# 265    0.625     437.0     437.0     273.125
# 266    0.625     470.0     470.0     293.750
# 267    0.625     483.0     483.0     301.875
#
#                                              SeriesUID ConvolutionKernel  \
# 0    1.2.840.113619.2.55.3.3852317604.741.128769737...              BONE
# 1    1.2.840.113619.2.55.3.3852317604.741.128769737...          STANDARD
# 2    1.2.840.113619.2.55.3.2831167752.727.122840803...              BONE
# 3    1.2.840.113619.2.55.3.2831167752.727.122840803...          STANDARD
# 4    1.2.840.113619.2.55.3.3852317604.390.127197598...          STANDARD
# ..                                                 ...               ...
# 263  1.2.840.113619.2.55.1.1762927041.1897.12426487...          STANDARD
# 264  1.2.840.113619.2.55.1.1762927041.1884.12235503...              BONE
# 265  1.2.840.113619.2.55.1.1762927041.1884.12235503...          STANDARD
# 266  1.2.840.113619.2.55.3.2831167752.127.127177625...              BONE
# 267  1.2.840.113619.2.55.3.2831167752.127.127177625...          STANDARD
#
#      SliceThickness    KVP  Reconstruction Diameter  Exposure Time  \
# 0             0.625  120.0                    322.0            500
# 1             0.625  120.0                    322.0            500
# 2             0.625  120.0                    360.0            500
# 3             0.625  120.0                    360.0            500
# 4             0.625  120.0                    353.0            500
# ..              ...    ...                      ...            ...
# 263           0.625  120.0                    369.0            478
# 264           0.625  120.0                    405.0            478
# 265           0.625  120.0                    360.0            478
# 266           0.625  120.0                    340.0            500
# 267           0.625  120.0                    340.0            500
#
#      X-Ray Tube Current  Exposure  Spiral Pitch Factor
# 0                   400         4                1.375
# 1                   100         1                1.375
# 2                   400         2                1.375
# 3                   100         0                1.375
# 4                   100         1                1.375
# ..                  ...       ...                  ...
# 263                 100      1189                  NaN
# 264                 400      4113                  NaN
# 265                 100      1039                  NaN
# 266                 400         2                1.375
# 267                 100         0                1.375
#
# [268 rows x 18 columns]

# %%
copd_ge = copd_ge.drop(columns = ["StudyDate", "Modality", "BodyPart"])
copd_ge
# Out:
#            PatientID        Manufacturer  Spacing  NumSlice  NumDICOM  \
# 0    COPDGene_A16009  GE MEDICAL SYSTEMS    0.625     522.0     522.0
# 1    COPDGene_A16009  GE MEDICAL SYSTEMS    0.625     507.0     507.0
# 2    COPDGene_A24802  GE MEDICAL SYSTEMS    0.625     584.0     584.0
# 3    COPDGene_A24802  GE MEDICAL SYSTEMS    0.625     489.0     489.0
# 4    COPDGene_A43240  GE MEDICAL SYSTEMS    0.625     469.0     469.0
# ..               ...                 ...      ...       ...       ...
# 263  COPDGene_P19505  GE MEDICAL SYSTEMS    0.625     503.0     503.0
# 264  COPDGene_Q59293  GE MEDICAL SYSTEMS    0.625     432.0     432.0
# 265  COPDGene_Q59293  GE MEDICAL SYSTEMS    0.625     437.0     437.0
# 266  COPDGene_Q70095  GE MEDICAL SYSTEMS    0.625     470.0     470.0
# 267  COPDGene_Q70095  GE MEDICAL SYSTEMS    0.625     483.0     483.0
#
#      ScanLength                                          SeriesUID  \
# 0       326.250  1.2.840.113619.2.55.3.3852317604.741.128769737...
# 1       316.875  1.2.840.113619.2.55.3.3852317604.741.128769737...
# 2       365.000  1.2.840.113619.2.55.3.2831167752.727.122840803...
# 3       305.625  1.2.840.113619.2.55.3.2831167752.727.122840803...
# 4       293.125  1.2.840.113619.2.55.3.3852317604.390.127197598...
# ..          ...                                                ...
# 263     314.375  1.2.840.113619.2.55.1.1762927041.1897.12426487...
# 264     270.000  1.2.840.113619.2.55.1.1762927041.1884.12235503...
# 265     273.125  1.2.840.113619.2.55.1.1762927041.1884.12235503...
# 266     293.750  1.2.840.113619.2.55.3.2831167752.127.127177625...
# 267     301.875  1.2.840.113619.2.55.3.2831167752.127.127177625...
#
#     ConvolutionKernel  SliceThickness    KVP  Reconstruction Diameter  \
# 0                BONE           0.625  120.0                    322.0
# 1            STANDARD           0.625  120.0                    322.0
# 2                BONE           0.625  120.0                    360.0
# 3            STANDARD           0.625  120.0                    360.0
# 4            STANDARD           0.625  120.0                    353.0
# ..                ...             ...    ...                      ...
# 263          STANDARD           0.625  120.0                    369.0
# 264              BONE           0.625  120.0                    405.0
# 265          STANDARD           0.625  120.0                    360.0
# 266              BONE           0.625  120.0                    340.0
# 267          STANDARD           0.625  120.0                    340.0
#
#      Exposure Time  X-Ray Tube Current  Exposure  Spiral Pitch Factor
# 0              500                 400         4                1.375
# 1              500                 100         1                1.375
# 2              500                 400         2                1.375
# 3              500                 100         0                1.375
# 4              500                 100         1                1.375
# ..             ...                 ...       ...                  ...
# 263            478                 100      1189                  NaN
# 264            478                 400      4113                  NaN
# 265            478                 100      1039                  NaN
# 266            500                 400         2                1.375
# 267            500                 100         0                1.375
#
# [268 rows x 15 columns]

# %%
#Count the total number of slices for all the patients having BONE and STANDARD kernels
total_slices_bone = copd_ge[copd_ge['ConvolutionKernel'] == 'BONE']['NumSlice'].sum()
total_slices_standard = copd_ge[copd_ge['ConvolutionKernel'] == 'STANDARD']['NumSlice'].sum()

total_slices_bone, total_slices_standard
# Out:
# (67109.0, 64837.0)

# %%
#Split the datframe into two dataframes. Dataframe 1 will have 100 subjects with pairs of BONE and STANDARD kernel. Dataframe 2 will have the remaining subjects.
grouped_copd = copd_ge.groupby(['PatientID']).size().reset_index(name = 'Counts')

# %%
grouped_copd
# Out:
#            PatientID  Counts
# 0    COPDGene_A00282       2
# 1    COPDGene_A09543       2
# 2    COPDGene_A16009       2
# 3    COPDGene_A24802       2
# 4    COPDGene_A43240       2
# ..               ...     ...
# 129  COPDGene_Q15613       2
# 130  COPDGene_Q53485       2
# 131  COPDGene_Q53566       2
# 132  COPDGene_Q59293       2
# 133  COPDGene_Q70095       2
#
# [134 rows x 2 columns]

# %%
#Random sample 100 subjects from the dataframe
copd_ge_100 = grouped_copd.sample(n=100, random_state=1)
copd_ge_100
# Out:
#            PatientID  Counts
# 42   COPDGene_F02607       2
# 36   COPDGene_D90444       2
# 93   COPDGene_M09479       2
# 5    COPDGene_A67397       2
# 65   COPDGene_H39589       2
# ..               ...     ...
# 109  COPDGene_N37247       2
# 88   COPDGene_L75615       2
# 8    COPDGene_B01752       2
# 81   COPDGene_L08729       2
# 60   COPDGene_H16787       2
#
# [100 rows x 2 columns]

# %%
#Get the remaining 34 subjects
remaining_subjects = grouped_copd.drop(copd_ge_100.index)
remaining_subjects
# Out:
#            PatientID  Counts
# 0    COPDGene_A00282       2
# 1    COPDGene_A09543       2
# 7    COPDGene_A90522       2
# 9    COPDGene_B02099       2
# 11   COPDGene_B11434       2
# 13   COPDGene_B25378       2
# 14   COPDGene_B26679       2
# 18   COPDGene_B68201       2
# 20   COPDGene_B87500       2
# 22   COPDGene_C03575       2
# 25   COPDGene_C33239       2
# 28   COPDGene_C75346       2
# 29   COPDGene_D00372       2
# 37   COPDGene_E06175       2
# 50   COPDGene_G18413       2
# 57   COPDGene_H00241       2
# 61   COPDGene_H17650       2
# 63   COPDGene_H20439       2
# 68   COPDGene_H83061       2
# 71   COPDGene_J33089       2
# 72   COPDGene_J37330       2
# 79   COPDGene_K68188       2
# 84   COPDGene_L33508       2
# 86   COPDGene_L64242       2
# 87   COPDGene_L70091       2
# 94   COPDGene_M44564       2
# 96   COPDGene_M56323       2
# 101  COPDGene_M94189       2
# 105  COPDGene_M99416       2
# 106  COPDGene_N11994       2
# 113  COPDGene_N78914       2
# 115  COPDGene_N99786       2
# 127  COPDGene_Q07585       2
# 129  COPDGene_Q15613       2

# %%
copd_remaining = copd_ge[copd_ge['PatientID'].isin(remaining_subjects['PatientID'])]
copd_remaining.to_csv("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/final_paired_data_spreadsheets/COPD_GE_pairedkernels_after100randomsamples.csv", index = False)
copd_remaining
# Out:
#            PatientID        Manufacturer  Spacing  NumSlice  NumDICOM  \
# 8    COPDGene_A90522  GE MEDICAL SYSTEMS    0.625     545.0     545.0
# 9    COPDGene_A90522  GE MEDICAL SYSTEMS    0.625     545.0     545.0
# 14   COPDGene_B11434  GE MEDICAL SYSTEMS    0.625     502.0     502.0
# 15   COPDGene_B11434  GE MEDICAL SYSTEMS    0.625     485.0     485.0
# 22   COPDGene_B68201  GE MEDICAL SYSTEMS    0.625     560.0     560.0
# ..               ...                 ...      ...       ...       ...
# 225  COPDGene_H00241  GE MEDICAL SYSTEMS    0.625     377.0     377.0
# 234  COPDGene_J37330  GE MEDICAL SYSTEMS    0.625     504.0     504.0
# 235  COPDGene_J37330  GE MEDICAL SYSTEMS    0.625     504.0     504.0
# 258  COPDGene_N78914  GE MEDICAL SYSTEMS    0.625     472.0     472.0
# 259  COPDGene_N78914  GE MEDICAL SYSTEMS    0.625     433.0     433.0
#
#      ScanLength                                          SeriesUID  \
# 8       340.625  1.2.840.113619.2.181.33975605383.32020.1229954...
# 9       340.625  1.2.840.113619.2.181.33975605383.32020.1229954...
# 14      313.750  1.2.840.113619.2.55.3.2831167752.584.123972287...
# 15      303.125  1.2.840.113619.2.55.3.2831167752.584.123972287...
# 22      350.000  1.2.840.113619.2.55.3.2831167752.561.121570247...
# ..          ...                                                ...
# 225     235.625    1.2.840.113619.2.25.1.1762927041.1274441843.126
# 234     315.000  1.2.840.113619.2.55.3.279720240.745.1255532321...
# 235     315.000  1.2.840.113619.2.55.3.279720240.745.1255532320...
# 258     295.000         1.2.840.113619.2.25.4.477398.1233714827.65
# 259     270.625        1.2.840.113619.2.25.4.477398.1233714914.853
#
#     ConvolutionKernel  SliceThickness    KVP  Reconstruction Diameter  \
# 8            STANDARD           0.625  120.0                    360.0
# 9                BONE           0.625  120.0                    360.0
# 14               BONE           0.625  120.0                    360.0
# 15           STANDARD           0.625  120.0                    360.0
# 22               BONE           0.625  120.0                    360.0
# ..                ...             ...    ...                      ...
# 225              BONE           0.625  120.0                    457.0
# 234          STANDARD           0.625  120.0                    360.0
# 235              BONE           0.625  120.0                    360.0
# 258              BONE           0.625  120.0                    360.0
# 259          STANDARD           0.625  120.0                    360.0
#
#      Exposure Time  X-Ray Tube Current  Exposure  Spiral Pitch Factor
# 8              500                 100         1                  NaN
# 9              500                 400         4                  NaN
# 14             500                 400         2                1.375
# 15             500                 100         0                1.375
# 22             500                 400         2                1.375
# ..             ...                 ...       ...                  ...
# 225            478                 400      3613                  NaN
# 234            500                 100         1                1.375
# 235            500                 400         2                1.375
# 258            478                 400         9                1.375
# 259            478                 100         2                1.375
#
# [68 rows x 15 columns]

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x = 'PatientID', data = copd_remaining, hue = "ConvolutionKernel")
plt.title("Count of kernels")
plt.show()

# %%
#Get the 100 subjects from copd_ge
copd_ge_100_sampled = copd_ge[copd_ge['PatientID'].isin(copd_ge_100['PatientID'])]
copd_ge_100_sampled.to_csv("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/final_paired_data_spreadsheets/COPD_GE_pairedkernels_100randomsamples.csv", index = False)
copd_ge_100_sampled
# Out:
#            PatientID        Manufacturer  Spacing  NumSlice  NumDICOM  \
# 0    COPDGene_A16009  GE MEDICAL SYSTEMS    0.625     522.0     522.0
# 1    COPDGene_A16009  GE MEDICAL SYSTEMS    0.625     507.0     507.0
# 2    COPDGene_A24802  GE MEDICAL SYSTEMS    0.625     584.0     584.0
# 3    COPDGene_A24802  GE MEDICAL SYSTEMS    0.625     489.0     489.0
# 4    COPDGene_A43240  GE MEDICAL SYSTEMS    0.625     469.0     469.0
# ..               ...                 ...      ...       ...       ...
# 263  COPDGene_P19505  GE MEDICAL SYSTEMS    0.625     503.0     503.0
# 264  COPDGene_Q59293  GE MEDICAL SYSTEMS    0.625     432.0     432.0
# 265  COPDGene_Q59293  GE MEDICAL SYSTEMS    0.625     437.0     437.0
# 266  COPDGene_Q70095  GE MEDICAL SYSTEMS    0.625     470.0     470.0
# 267  COPDGene_Q70095  GE MEDICAL SYSTEMS    0.625     483.0     483.0
#
#      ScanLength                                          SeriesUID  \
# 0       326.250  1.2.840.113619.2.55.3.3852317604.741.128769737...
# 1       316.875  1.2.840.113619.2.55.3.3852317604.741.128769737...
# 2       365.000  1.2.840.113619.2.55.3.2831167752.727.122840803...
# 3       305.625  1.2.840.113619.2.55.3.2831167752.727.122840803...
# 4       293.125  1.2.840.113619.2.55.3.3852317604.390.127197598...
# ..          ...                                                ...
# 263     314.375  1.2.840.113619.2.55.1.1762927041.1897.12426487...
# 264     270.000  1.2.840.113619.2.55.1.1762927041.1884.12235503...
# 265     273.125  1.2.840.113619.2.55.1.1762927041.1884.12235503...
# 266     293.750  1.2.840.113619.2.55.3.2831167752.127.127177625...
# 267     301.875  1.2.840.113619.2.55.3.2831167752.127.127177625...
#
#     ConvolutionKernel  SliceThickness    KVP  Reconstruction Diameter  \
# 0                BONE           0.625  120.0                    322.0
# 1            STANDARD           0.625  120.0                    322.0
# 2                BONE           0.625  120.0                    360.0
# 3            STANDARD           0.625  120.0                    360.0
# 4            STANDARD           0.625  120.0                    353.0
# ..                ...             ...    ...                      ...
# 263          STANDARD           0.625  120.0                    369.0
# 264              BONE           0.625  120.0                    405.0
# 265          STANDARD           0.625  120.0                    360.0
# 266              BONE           0.625  120.0                    340.0
# 267          STANDARD           0.625  120.0                    340.0
#
#      Exposure Time  X-Ray Tube Current  Exposure  Spiral Pitch Factor
# 0              500                 400         4                1.375
# 1              500                 100         1                1.375
# 2              500                 400         2                1.375
# 3              500                 100         0                1.375
# 4              500                 100         1                1.375
# ..             ...                 ...       ...                  ...
# 263            478                 100      1189                  NaN
# 264            478                 400      4113                  NaN
# 265            478                 100      1039                  NaN
# 266            500                 400         2                1.375
# 267            500                 100         0                1.375
#
# [200 rows x 15 columns]

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x = 'PatientID', data = copd_ge_100_sampled, hue = "ConvolutionKernel")
plt.title("Count of kernels")
plt.show()

# %%
#Count the total number of slices for all the patients having BONE and STANDARD kernels
total_slices_bone = copd_ge_100_sampled[copd_ge_100_sampled['ConvolutionKernel'] == 'BONE']['NumSlice'].sum()
total_slices_standard = copd_ge_100_sampled[copd_ge_100_sampled['ConvolutionKernel'] == 'STANDARD']['NumSlice'].sum()

total_slices_bone, total_slices_standard
# Out:
# (50094.0, 48581.0)

# %% [markdown]
# ### GOLD Classification

# %%
gold_copd_ge = pd.read_csv("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/copdgene_goldcriteria_SPIE_data_GEkernels_paired_inspexpscans_ONLY.csv")
gold_copd_ge
# Out:
#                                               File_Path        PatientID  \
# 0     /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_A00282
# 1     /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_A00282
# 2     /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_A05113
# 3     /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_A05113
# 4     /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_A08860
# ...                                                 ...              ...
# 1505  /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_Q70095
# 1506  /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_Q72811
# 1507  /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_Q72811
# 1508  /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_Q73716
# 1509  /fs5/p_masi/krishar1/COPDGENE/SPIE_2025/COPDGe...  COPDGene_Q73716
#
#      ConvolutionKernel           SeriesDescription        Manufacturer  \
# 0                 BONE  COPDGene_A00282_INSP_SHARP  GE MEDICAL SYSTEMS
# 1             STANDARD     COPDGene_A00282_EXP_STD  GE MEDICAL SYSTEMS
# 2                 BONE  COPDGene_A05113_INSP_SHARP  GE MEDICAL SYSTEMS
# 3             STANDARD     COPDGene_A05113_EXP_STD  GE MEDICAL SYSTEMS
# 4                 BONE  COPDGene_A08860_INSP_SHARP  GE MEDICAL SYSTEMS
# ...                ...                         ...                 ...
# 1505              BONE  COPDGene_Q70095_INSP_SHARP  GE MEDICAL SYSTEMS
# 1506          STANDARD     COPDGene_Q72811_EXP_STD  GE MEDICAL SYSTEMS
# 1507              BONE  COPDGene_Q72811_INSP_SHARP  GE MEDICAL SYSTEMS
# 1508              BONE  COPDGene_Q73716_INSP_SHARP  GE MEDICAL SYSTEMS
# 1509          STANDARD     COPDGene_Q73716_EXP_STD  GE MEDICAL SYSTEMS
#
#      Inspiration_Expiration
# 0                INSP_SHARP
# 1                   EXP_STD
# 2                INSP_SHARP
# 3                   EXP_STD
# 4                INSP_SHARP
# ...                     ...
# 1505             INSP_SHARP
# 1506                EXP_STD
# 1507             INSP_SHARP
# 1508             INSP_SHARP
# 1509                EXP_STD
#
# [1510 rows x 6 columns]

# %%
gold_copd = pd.read_csv("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/COPD_gene_COPDsubjects.csv")
gold_copd
# Out:
#      Body Site Case/control  Consent code Consent Downloaded  \
# 0        chest         case             2   DS-CS        Yes
# 1        chest         case             2   DS-CS        Yes
# 2        chest         case             1     HMB        Yes
# 3        chest         case             1     HMB        Yes
# 4        chest         case             1     HMB        Yes
# ...        ...          ...           ...     ...        ...
# 2767     chest         case             1     HMB        Yes
# 2768     chest         case             1     HMB        Yes
# 2769     chest         case             1     HMB        Yes
# 2770     chest         case             1     HMB        Yes
# 2771     chest         case             1     HMB        Yes
#
#                             File Name  Study PHS GOLD classification  \
# 0                     COPDGene_A00282  phs000179              GOLD_3
# 1     COPDGene_A00282_COPDGene_A00282  phs000179              GOLD_3
# 2                     COPDGene_A04808  phs000179              GOLD_3
# 3     COPDGene_A04808_COPDGene_A04808  phs000179              GOLD_3
# 4     COPDGene_A05032_COPDGene_A05032  phs000179              GOLD_2
# ...                               ...        ...                 ...
# 2767  COPDGene_Q75550_COPDGene_Q75550  phs000179              GOLD_3
# 2768  COPDGene_Q75847_COPDGene_Q75847  phs000179              GOLD_2
# 2769  COPDGene_Q77447_COPDGene_Q77447  phs000179              GOLD_2
# 2770  COPDGene_Q77609_COPDGene_Q77609  phs000179              GOLD_2
# 2771  COPDGene_Q78049_COPDGene_Q78049  phs000179              GOLD_4
#
#      Image type  local_id        Population     Sex
# 0            CT  d1992781         Caucasian  female
# 1            CT  d1984662         Caucasian  female
# 2            CT  d1990454           African    male
# 3            CT  d1975491  African American    male
# 4            CT  d1978067         Caucasian    male
# ...         ...       ...               ...     ...
# 2767         CT  d1980079         Caucasian  female
# 2768         CT  d1979186         Caucasian  female
# 2769         CT  d1978508         Caucasian    male
# 2770         CT  d1978509         Caucasian    male
# 2771         CT  d1980510         Caucasian  female
#
# [2772 rows x 12 columns]
