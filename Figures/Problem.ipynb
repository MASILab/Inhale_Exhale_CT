# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns 
import nibabel as nib

# %%
#Inspiratory BONE and Expiratory STANDARD middle slice from the same subject 
insp_bone = nib.load("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/data_split/valid/inspiratory_BONE/COPDGene_F02607_BONE.nii.gz").get_fdata()
exp_std = nib.load("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/data_split/valid/expiratory_STANDARD/COPDGene_F02607_STANDARD.nii.gz").get_fdata()

ix,iy,iz = insp_bone.shape
ex,ey,ez = exp_std.shape

mid_iz = iz//2
mid_ez = ez//2

insp_bone_mid = insp_bone[:,:,mid_iz]
exp_std_mid = exp_std[:,:,mid_ez]

plt.figure(figsize=(16,16))
plt.imshow(np.rot90(exp_std_mid), cmap='gray', vmin=-150, vmax=150)
plt.axis('off')
plt.savefig("/nfs/masi/krishar1/SPIE_2025_InhaleExhaleCT/SPIE_paper_figures/Problem_figure/exp_std_muscfatwindow.tiff", dpi=300, format='tiff')
plt.show()
